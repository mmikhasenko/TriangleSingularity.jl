# %% [markdown]
# # Triangle diagram
# In this notebook, I calculate a triangle diagram for an arbitrary case
# Internal masses are noted $m_i$, $i=1,2,3$, The symmetric external masses are noted by $M_i$, $i=1,2,3$.
#
# The fuction ```Isc(m1sq,m2sq,m3sq,M1sq,M2sq,M3sq)``` calculates amplitude for the triangle graph, shown in the figure below.
# ![Triangle diagram to introduce notations](pict/triangle.png)

# %%
using QuadGK
function IscIntegrand(x, m1sq, m2sq, m3sq, M1sq, M2sq, M3sq)
    Ay = M1sq;
    By = m2sq + x*M2sq - (1-x)*M1sq - x*M3sq-m3sq;
    Cy = x*m1sq + (1-x)*m3sq - x*(1-x)*M2sq;
    Dy = By^2-4*Ay*Cy;
    y1, y2 = (-By-sqrt(Dy)*[1.0, -1.0])/(2*Ay);
    return (log((1-x-y2)/(-y2))-log((1-x-y1)/(-y1)))/(Ay*(y2-y1))
end

function Isc(m1sq, m2sq, m3sq, M1sq, M2sq, M3sq)
    integr = quadgk(x->IscIntegrand(x, m1sq, m2sq, m3sq, M1sq, M2sq, M3sq), 0, 1)[1];
    return integr/(16*π^2);
end
# Out:
# Isc (generic function with 1 method)

# %%
using Plots

# %% [markdown]
# ## Triangle for the $a_1(1420)$
# Please find details in a paper by Mikhasenko at.al [Phys.Rev. D91 (2015) no.9, 094015]

# %%
ell = linspace(1.3,1.6,100)
mπ = 0.139;
mKp = 0.4936;
mKs = 0.892;
ΓKs = 0.001;  # to demonstrate it better
mf0 = 0.99;
data_a1 = [Isc(mKs^2-1im*mKs*ΓKs,mKp^2,mKp^2,mf0^2,mπ^2,e^2) for e in ell];

# %%
plot(ell,real(data_a1), lab="Re")
plot!(ell,imag(data_a1), lab="Im")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.3701,370.85 39.3701,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   223.622,370.85 223.622,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   407.874,370.85 407.874,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   592.126,370.85 592.126,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,366.732 583.835,366.732
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,209.521 583.835,209.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,52.3095 583.835,52.3095
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 592.126,376.378
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   223.622,376.378 223.622,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   407.874,376.378 407.874,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,376.378 592.126,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,366.732 47.6614,366.732
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,209.521 47.6614,209.521
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,52.3095 47.6614,52.3095
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 390.178)" x="39.3701" y="390.178">1.3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 223.622, 390.178)" x="223.622" y="390.178">1.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 407.874, 390.178)" x="407.874" y="390.178">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 390.178)" x="592.126" y="390.178">1.6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 371.232)" x="33.3701" y="371.232">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 214.021)" x="33.3701" y="214.021">0.1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 56.8095)" x="33.3701" y="56.8095">0.2</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,287.816 44.9535,286.714 50.5369,285.564 56.1203,284.362 61.7037,283.103 67.287,281.784 72.8704,280.399 78.4538,278.942 84.0372,277.406 89.6206,275.785
#   95.204,274.069 100.787,272.248 106.371,270.31 111.954,268.243 117.538,266.03 123.121,263.652 128.704,261.085 134.288,258.301 139.871,255.265 145.455,251.933
#   151.038,248.246 156.621,244.13 162.205,239.479 167.788,234.145 173.372,227.905 178.955,220.392 184.538,210.931 190.122,197.971 195.705,175.424 201.288,159.668
#   206.872,160.77 212.455,162.733 218.039,165.006 223.622,167.564 229.205,170.597 234.789,174.817 240.372,184.146 245.956,310.644 251.539,366.183 257.122,371.383
#   262.706,373.246 268.289,374.192 273.873,374.757 279.456,375.13 285.039,375.392 290.623,375.585 296.206,375.732 301.79,375.846 307.373,375.937 312.956,376.011
