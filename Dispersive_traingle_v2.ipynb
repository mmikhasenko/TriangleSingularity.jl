# %% [markdown]
# # Dispersive calculation of triangle diagram
# 03.2018 / Misha Mikhasenko

# %%
const m1sq = 5.619^2
const m2sq = 0.4936^2
const m3sq = 3.510^2
const m4sq = 0.938^2
const th34 = (sqrt(m3sq)+sqrt(m4sq))^2
const th24 = (sqrt(m2sq)+sqrt(m4sq))^2;

# %% [markdown]
# Thresholds in $s$-channel

# %%
(sqrt(m3sq)-sqrt(m4sq)), (sqrt(m3sq)+sqrt(m4sq)), (sqrt(m1sq)-sqrt(m2sq)), (sqrt(m1sq)+sqrt(m2sq))
# Out:
# (2.572, 4.4479999999999995, 5.1254, 6.1126)

# %% [markdown]
# ### Projection to the cross-channel using dispersive representation
#
# The required projection reads
# $$
# b(s) = \int_{-1}^{1}\frac{\mathrm{d}z}{2} B(t(z,s)) = \frac{1}{4pq}\int_{t_\text{min}}^{t_\text{max}} \mathrm{d} t \,B(t(z,s)).
# $$
# The scattering amplitude $B(t)$ is given by the dispersive integral
# $$
# B(t) = \frac{1}{\pi}\int_{\text{th}}^{\infty}  \frac{\text{Im}B(t)}{t'-t-i0}
# $$
#
# The result in integration over $t$ is
# $$
# b(s) = \frac{1}{\pi}\int_{\text{th}}^{\infty} \mathrm{d}t'\,\text{Im} B(t') f(t',s),
# $$
# where $f(t',s)$ is an analytic function:
# $$
# f(t',s) = \frac{1}{4pq}\left[\log(t'-t_\text{min})-\log(t'-t_\text{max})\right]
# $$
# and $t_\text{min}$, $t_\text{max}$ are given by
# $$
# t_{\text{max/min}} = m_1^2+m_3^2-\frac{(s+m_1^2-m_2^2)(s+m_3^2-m_4^2)}{2s} \pm 2pq
# $$
#
# #### It is extremely important to choose correctly the branching cuts in $pq$
# $$
# 4s\,pq = \sqrt{m_1^2 - (\sqrt{s}-m_2)^2}\sqrt{m_1^2 - (\sqrt{s}+m_2)^2} \lambda^{1/2}(s,m_3^2,m_4^2)
# $$
# To select a correct sheet I use the Bronzan-Kascer prescription $m_1^2 \to m_1^2 + i\epsilon$, see [Phys.Rev.132 (1963)].

# %%
λ(x,y,z) = x^2+y^2+z^2-2x*y-2y*z-2z*x
function tmin(s)
    m1sq_ph = m1sq+1e-6im  # Bronzan-Kascer
    pq = sqrt(m1sq_ph-(sqrt(s)+sqrt(m2sq))^2)*
         sqrt(m1sq_ph-(sqrt(s)-sqrt(m2sq))^2)*
        sqrt(λ(s,m3sq,m4sq))/(4s)
    m3sq+m1sq_ph-(s+m1sq_ph-m2sq)*(s+m3sq-m4sq)/(2s)-2pq
end
function tmax(s)
    m1sq_ph = m1sq+1e-6im  # Bronzan-Kascer
    pq = sqrt(m1sq_ph-(sqrt(s)+sqrt(m2sq))^2)*
         sqrt(m1sq_ph-(sqrt(s)-sqrt(m2sq))^2)*
        sqrt(λ(s,m3sq,m4sq))/(4s)
    m3sq+m1sq_ph-(s+m1sq_ph-m2sq)*(s+m3sq-m4sq)/(2s)+2pq
end
function f_proj_disp(t,s)
    m1sq_ph = m1sq+1e-6im  # Bronzan-Kascer
    pq = sqrt(m1sq_ph-(sqrt(s)+sqrt(m2sq))^2)*
         sqrt(m1sq_ph-(sqrt(s)-sqrt(m2sq))^2)*
        sqrt(λ(s,m3sq,m4sq))/(4s)
    # 
    (log(t-tmin(s))-log(t-tmax(s)))/(4pq)
end
# Out:
# f_proj_disp (generic function with 1 method)

# %% [markdown]
# ### The movement of $t_\text{min/max}$ as a function of $s$

# %%
using Plots

# %%
ev = linspace(sqrt(th34)+1e-4,6.5,400)
tmin_v = [tmin(e^2) for e in ev]
tmax_v = [tmax(e^2) for e in ev]
plot(
    plot(ev, [imag(tmin_v), imag(tmax_v)], lab = ["tmin" "tmax"], title="Imaginary part", leg=:bottomleft, xlab="e (GeV)"),
    plot(ev, [real(tmin_v), real(tmax_v)], lab = ["tmin" "tmax"], title="Real part", leg=:bottomleft, xlab="e (GeV)"),
    plot([real(tmin_v), real(tmax_v)], [imag(tmin_v), imag(tmax_v)], lab = ["tmin" "tmax"],
        title="In complex t-plane", leg=:bottomleft, xlab="real part", ylab="imag part"),
    layout=grid(1,3), size=(900,300)
    )
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="900" height="300" viewBox="0 0 900 300">
# <defs>
#   <clipPath id="clip0700">
#     <rect x="0" y="0" width="900" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,300 900,300 900,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0701">
#     <rect x="180" y="0" width="631" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 39.502,260.121 278.411,260.121 278.411,31.4961 39.502,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0702">
#     <rect x="39" y="31" width="240" height="230"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.5449,260.121 45.5449,31.4961
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   103.761,260.121 103.761,31.4961
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   161.978,260.121 161.978,31.4961
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   220.194,260.121 220.194,31.4961
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.411,260.121 278.411,31.4961
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.502,257.366 278.411,257.366
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.502,220.18 278.411,220.18
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.502,182.994 278.411,182.994
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.502,145.808 278.411,145.808
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.502,108.622 278.411,108.622
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.502,71.4363 278.411,71.4363
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.502,34.2503 278.411,34.2503
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,260.121 278.411,260.121
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,260.121 39.502,31.4961
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.5449,260.121 45.5449,256.691
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   103.761,260.121 103.761,256.691
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   161.978,260.121 161.978,256.691
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.194,260.121 220.194,256.691
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.411,260.121 278.411,256.691
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,257.366 43.0856,257.366
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,220.18 43.0856,220.18
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,182.994 43.0856,182.994
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,145.808 43.0856,145.808
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,108.622 43.0856,108.622
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,71.4363 43.0856,71.4363
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.502,34.2503 43.0856,34.2503
#   "/>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.5449, 275.421)" x="45.5449" y="275.421">4.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 103.761, 275.421)" x="103.761" y="275.421">5.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 161.978, 275.421)" x="161.978" y="275.421">5.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 220.194, 275.421)" x="220.194" y="275.421">6.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.411, 275.421)" x="278.411" y="275.421">6.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.502, 261.866)" x="30.502" y="261.866">-1.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.502, 224.68)" x="30.502" y="224.68">-1.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.502, 187.494)" x="30.502" y="187.494">-0.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.502, 150.308)" x="30.502" y="150.308">0.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.502, 113.122)" x="30.502" y="113.122">0.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.502, 75.9363)" x="30.502" y="75.9363">1.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.502, 38.7503)" x="30.502" y="38.7503">1.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 158.956, 18)" x="158.956" y="18">Imaginary part</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fil

# %% [markdown]
# Plot function $f(t,s = \text{fixed})$

# %%
let s = 4.5^2
    tv = linspace(th24,10,200)
    cal = f_proj_disp.(tv,s)
    plot(tv, real(cal), lab="real f(t,s=$s)")
    plot!(tv, imag(cal), lab="imag f(t,s=$s)")
end
plot!(xlab = "t (GeV)", ylab = "f(t,s)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
#
)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 29.1292,375.869 580.315,375.869 580.315,11.811 29.1292,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1102">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   94.105,375.869 94.105,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   164.587,375.869 164.587,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   235.07,375.869 235.07,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   305.552,375.869 305.552,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   376.034,375.869 376.034,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   446.517,375.869 446.517,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   516.999,375.869 516.999,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,303.139 580.315,303.139
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,230.235 580.315,230.235
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,157.33 580.315,157.33
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,84.4255 580.315,84.4255
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,375.869 29.1292,11.811
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   94.105,375.869 94.105,370.408
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   164.587,375.869 164.587,370.408
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   235.07,375.869 235.07,370.408
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   305.552,375.869 305.552,370.408
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   376.034,375.869 376.034,370.408
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   446.517,375.869 446.517,370.408
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   516.999,375.869 516.999,370.408
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,303.139 37.397,303.139
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,230.235 37.397,230.235
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,157.33 37.397,157.33
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,84.4255 37.397,84.4255
#   "/>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 94.105, 389.669)" x="94.105" y="389.669">1.25</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 164.587, 389.669)" x="164.587" y="389.669">1.50</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 235.07, 389.669)" x="235.07" y="389.669">1.75</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 305.552, 389.669)" x="305.552" y="389.669">2.00</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 376.034, 389.669)" x="376.034" y="389.669">2.25</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 446.517, 389.669)" x="446.517" y="389.669">2.50</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 516.999, 389.669)" x="516.999" y="389.669">2.75</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 307.639)" x="23.1292" y="307.639">20</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 234.735)" x="23.1292" y="234.735">40</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 161.83)" x="23.1292" y="161.83">60</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 88.9255)" x="23.1292" y="88.9255">80</text>
# </g>
# <polyline clip-path="url(#clip1102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,375.698 80.0451,375.594 110.643,375.494 136.514,375.37 164.617,375.165 190.525,374.858 218.301,374.262 250.482,372.627 264.782,370.979 279.082,367.657
#   285.351,365.023 291.621,360.887 294.756,357.874 297.891,353.862 301.026,348.366 304.16,340.581 305.869,334.911 307.578,327.817 309.287,318.817 310.996,307.223
#   311.851,300.162 312.705,292.06 313.56,282.729 314.414,271.954 315.268,259.484 316.123,245.042 316.977,228.333 317.832,209.078 318.686,187.064 319.541,162.248
#   320.395,134.906 321.25,105.837 322.104,76.581 322.959,49.5378 323.386,37.7971 323.813,27.7933 324.24,19.9187 324.667,14.5091 325.095,11.811 325.522,11.9548
#   325.949,14.9399 326.376,20.6347 326.804,28.7912 327.231,39.0712 327.658,51.0797 328.085,

# %% [markdown]
# Calculate the projection:
# $$
# b(s) = \frac{1}{\pi}\int_{\text{th}}^{\infty} \mathrm{d}t'\,\text{Im} B(t') f(t',s),
# $$

# %%
using QuadGK # intgration package

# %%
function bλ_proj(s)
    function integrand(θ)
        tp = th24+tan(θ)
        ImB(tp)*f_proj_disp(tp,s)/cos(θ)^2
    end
    sqrt(λ(s,m3sq,m4sq))*(quadgk(integrand,0,π/2)[1]/π)::Complex{Float64}
end
# Out:
# bλ_proj (generic function with 1 method)

# %% [markdown]
# For taking the integral to $\inf$, I use $t = \text{th}_{24}+\tan(\theta)$ substitution. The jacobian is $1/\cos^2(\theta)$.

# %% [markdown]
# That is how the projection look like.

# %%
ev = linspace(sqrt(th34)+1e-6,5.5,100)
cal = [bλ_proj(e^2) for e in ev]
plot(ev, real(cal), lab="real b(s)")
plot!(ev, imag(cal), lab="imag b(s)")
vline!([(sqrt(m1sq)-sqrt(m2sq))], ls=:dash, lab="pseudothreshold")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1300)" points="
#
# A(s) = \frac{1}{\pi}\int_{(m_3+m_4)^2}^{\infty} \frac{\lambda^{1/2}(s',m_3^2,m_4^2)\, b(s')}{s'(s'-s-i0)} \mathrm{d}s'
# $$

# %%
function A(s)
    function integrand(θ)
        sp = th34+tan(θ)
        bλ_proj(sp)/sp/(sp-s-1e-6im)/cos(θ)^2
    end
    (quadgk(integrand,0,π/2)[1]/π)::Complex{Float64}
end
# Out:
# A (generic function with 1 method)

# %% [markdown]
# I think the calculations can be speeded up by combining integrals to one 2d-simultaniously.

# %%
@time A(4.4^2)
# Out:
#   1.677166 seconds (1.50 M allocations: 33.134 MiB, 0.74% gc time)
# 3.324111424862469 + 1.254270326487358im

# %%
ev = linspace(3.3,5.5,50)
cal = [begin v = A(e^2); println("e = $(round(e,2)) -> $v"); v end for e in ev]
plot(ev, real(cal), lab="real A(s)")
plot!(ev, imag(cal), lab="imag A(s)")
vline!([(sqrt(m1sq)-sqrt(m2sq))], ls=:dash, lab="pseudothreshold")
# Out:
# e = 3.3 -> 1.2436464537710759 + 0.26305321832385115im
# e = 3.34 -> 1.2641696940002838 + 0.2703279167593806im
# e = 3.39 -> 1.285919512085706 + 0.27812778910522024im
# e = 3.43 -> 1.3090113301858342 + 0.2865099362767393im
# e = 3.48 -> 1.3335766466746273 + 0.2955401745034895im
# e = 3.52 -> 1.3597660598606958 + 0.30529477719169407im
# e = 3.57 -> 1.387753026258111 + 0.31586265584642786im
# e = 3.61 -> 1.4177385768757322 + 0.32734811606411524im
# e = 3.66 -> 1.4499572983458744 + 0.3398743754672168im
# e = 3.7 -> 1.4846850066140616 + 0.3535881039828715im
# e = 3.75 -> 1.5222487195617485 + 0.3686653549988387im
# e = 3.79 -> 1.5630398044175773 + 0.3853194179689669im
# e = 3.84 -> 1.6075315917801447 + 0.40381137098971304im
# e = 3.88 -> 1.6563034069794051 + 0.4244645002403932im
# e = 3.93 -> 1.7100740442593287 + 0.44768437769722497im
# e = 3.97 -> 1.7697495219943504 + 0.47398742319602893im
# e = 4.02 -> 1.8364931349798381 + 0.5040425507563119im
# e = 4.06 -> 1.9118316477774895 + 0.5387336633381835im
# e = 4.11 -> 1.9978227477009296 + 0.5792566748732271im
# e = 4.15 -> 2.0973321369663322 + 0.6272764310368615im
# e = 4.2 -> 2.2145206141487463 + 0.6851936582495102im
# e = 4.24 -> 2.355769823274587 + 0.7566292342150136im
# e = 4.29 -> 2.5316376102529667 + 0.8473810033093431im
# e = 4.33 -> 2.7616661161530143 + 0.9675573742608663im
# e = 4.38 -> 3.0894805336066917 + 1.1373399165823634im
# e = 4.42 -> 3.66164638925571 + 1.4100438054161477im
# e = 4.47 -> 4.564064334728591 + 3.0778401518771394im
# e = 4.51 -> 3.3707655988126626 + 5.0807683005013855im
# e = 4.56 -> 1.0309248551697048 + 4.966429985291621im
# e = 4.6 -> 0.2771868618770395 + 4.054885026617787im
# e = 4.65 -> 0.015396835101716242 + 3.4796783116743106im
# e = 4.69 -> -0.11145794182251767 + 3.0915600440122897im
# e = 4.74 -> -0.1847716992154601 + 2.807202785923945im
# e = 4.78 -> -0.23167824279637478 + 2.5866517246118192im
# e = 4.83 -> -0.26367447127502314 + 2.408604433157642im
# e = 4.87 -> -0.2864473442670363 + 2.2605929415063484im
# e = 4.92 -> -0.30312898224984347 + 2.1347752319025486im
# e = 4.96 -> -0.31558588373790186 + 2.0259358258998637im
# e = 5.01 -> -0.32499938851157295 + 1.930449474838106im
# e = 5.05 -> -0.3321535476594391 + 1.8457046893488052im
# e = 5.1 -> -0.3375891139857599 + 1.7697641152652663im
# e = 5.14 -> -0.34169101209533004 + 1.7011546763179668im
# e = 5.19 -> -0.34474060459943495 + 1.6387326375887283im
# e = 5.23 -> -0.3469482277035481 + 1.5815938671475855im
# e = 5.28 -> -0.34847418959560195 + 1.5290124012100246im
# e = 5.32 -> -0.34944272286694844 + 1.4803972958595724im
# e = 5.37 -> -0.3499515278729086 + 1.4352616706880248im
# e = 5.41 -> -0.3500784235638761 + 1.393200033643614im
# e = 5.46 -> -0.34988611045740287 + 1.3538714236028628im
# e = 5.5 -> -0.34942561677218903 + 1.3169866220201094im
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1500)" points="
# 22.4386,375.869 580.315,375.869 580.315,11.811 22.4386,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1502">
#     <rect x="22" y="11" width="559" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.1546,375.869 73.1546,11.811
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   199.945,375.869 199.945,11.811
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   326.735,375.869 326.735,11.811
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   453.525,375.869 453.525,11.811
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.869 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.4386,352.401 580.315,352.401
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.4386,285.366 580.315,285.366
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.4386,218.331 580.315,218.331
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.4386,151.296 580.315,151.296
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.4386,84.2605 580.315,84.2605
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.4386,17.2253 580.315,17.2253
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,375.869 22.4386,11.811
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.1546,375.869 73.1546,370.408
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   199.945,375.869 199.945,370.408
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   326.735,375.869 326.735,370.408
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   453.525,375.869 453.525,370.408
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.869 580.315,370.408
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,352.401 30.8068,352.401
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,285.366 30.8068,285.366
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,218.331 30.8068,218.331
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,151.296 30.8068,151.296
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,84.2605 30.8068,84.2605
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,17.2253 30.8068,17.2253
#   "/>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 73.1546, 389.669)" x="73.1546" y="389.669">3.5</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 199.945, 389.669)" x="199.945" y="389.669">4.0</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 326.735, 389.669)" x="326.735" y="389.669">4.5</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 453.525, 389.669)" x="453.525" y="389.669">5.0</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.669)" x="580.315" y="389.669">5.5</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.4386, 356.901)" x="16.4386" y="356.901">0</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.4386, 289.866)" x="16.4386" y="289.866">1</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.4386, 222.831)" x="16.4386" y="222.831">2</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.4386, 155.796)" x="16.4386" y="155.796">3</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.4386, 88.7605)" x="16.4386" y="88.7605">4</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.4386, 21.7253)" x="16.4386" y="21.7253">5</text>
# </g>
# <polyline clip-path="url(#clip1502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.4386,269.033 33.8238,267.657 45.2091,266.199 56.5943,264.651 67.9795,263.005 79.3648,261.249 90.75,259.373 102.135,257.363 113.52,255.203 124.906,252.875
#   136.291,250.357 147.676,247.623 159.061,244.64 170.447,241.371 181.832,237.766 193.217,233.766 204.602,229.292 215.988,224.241 227.373,218.477 238.758,211.806
#   250.143,203.95 261.528,194.482 272.914,182.692 284.299,167.272 295.684,145.297 307.069,106.942 318.455,46.4484 329.84,126.441 341.225,283.293 352.61,333.82
#   363.996,351.369 375.381,359.873 386.766,364.787 398.151,367.932 409.536,370.077 420.922,371.603 432.307,372.721 443.692,373.556 455.077,374.188 466.463,374.667
#   477.848,375.031 489.233,375.306 500.618,375.511 512.004,375.659 523.389,375.761 534.7

# %% [markdown]
# The result matches Feynman method!
